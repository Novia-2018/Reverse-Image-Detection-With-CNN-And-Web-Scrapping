# %% [markdown]
# ## Importing Libraries

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /opt/miniconda3/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /opt/miniconda3/lib/python3.7/site-packages (from h5py) (1.19.0)
# Requirement already satisfied: six in /opt/miniconda3/lib/python3.7/site-packages (from h5py) (1.15.0)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# %%
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Import the Fashion MNIST dataset

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# ## Analysing the dataset

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels) #there are 60,000 labels in the training set
# Out:
# 60000

# %%
train_labels # Each label is an integer between o and 9
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape #There are 10,000 images in the test set. Again, each image is represented as 28 x 28 pixels
# Out:
# (10000, 28, 28)

# %%
len(test_labels)# And the test set contains 10,000 images labels
# Out:
# 10000

# %% [markdown]
# # Preprocessing the data

# %% [raw]
# The data must be preprocessed before training the neural network. If we inspect the first and second image in the training set, we  see that the pixel values fall in the range of 0 to 255

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure()
plt.imshow(test_images[1])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [raw]
# Before feeding the values into the nural network we scale them ,To do so, divide the values by 255

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [raw]
# To verify that the data is in the correct format , let's display the first 20 images from the training set and display the class name below each image.

# %% [markdown]
# ###  Training Set

# %%
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ### Test Set

# %%
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[test_labels[i]])
plt.show()

# %% [markdown]
# # Build the model

# %%
cnn = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)
])

# %% [markdown]
# # Compile The Model

# %%
cnn.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# # Train the model

# %%
history = cnn.fit(train_images, train_labels, epochs=25, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4989 - accuracy: 0.8238 - val_loss: 0.4573 - val_accuracy: 0.8324
# Epoch 2/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3693 - accuracy: 0.8676 - val_loss: 0.3874 - val_accuracy: 0.8629
# Epoch 3/25
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3329 - accuracy: 0.8784 - val_loss: 0.3646 - val_accuracy: 0.8699
# Epoch 4/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3088 - accuracy: 0.8860 - val_loss: 0.3556 - val_accuracy: 0.8741
# Epoch 5/25
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2912 - accuracy: 0.8919 - val_loss: 0.3422 - val_accuracy: 0.8790
# Epoch 6/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2780 - accuracy: 0.8975 - val_loss: 0.3565 - val_accuracy: 0.8778
# Epoch 7/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2645 - accuracy: 0.9008 - val_loss: 0.3514 - val_accuracy: 0.8768
# Epoch 8/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2550 - accuracy: 0.9043 - val_loss: 0.3854 - val_accuracy: 0.8646
# Epoch 9/25
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2457 - accuracy: 0.9085 - val_loss: 0.3339 - val_accuracy: 0.8824
# Epoch 10/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2359 - accuracy: 0.9103 - val_loss: 0.3350 - val_accuracy: 0.8850
# Epoch 11/25
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2299 - accuracy: 0.9131 - val_loss: 0.3477 - val_accuracy: 0.8819
# Epoch 12/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2192 - accuracy: 0.9173 - val_loss: 0.3379 - val_accuracy: 0.8846
# Epoch 13/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2129 - accuracy: 0.9198 - val_loss: 0.3317 - val_accuracy: 0.8902
# Epoch 14/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2082 - accuracy: 0.9218 - val_loss: 0.3378 - val_accuracy: 0.8878
# Epoch 15/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1999 - accuracy: 0.9253 - val_loss: 0.3465 - val_accuracy: 0.8838
# Epoch 16/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1961 - accuracy: 0.9267 - val_loss: 0.3476 - val_accuracy: 0.8860
# Epoch 17/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1909 - accuracy: 0.9284 - val_loss: 0.3373 - val_accuracy: 0.8878
# Epoch 18/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1849 - accuracy: 0.9306 - val_loss: 0.3611 - val_accuracy: 0.8827
# Epoch 19/25
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1809 - accuracy: 0.9331 - val_loss: 0.3644 - val_accuracy: 0.8836
# Epoch 20/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1772 - accuracy: 0.9328 - val_loss: 0.3617 - val_accuracy: 0.8887
# Epoch 21/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1712 - accuracy: 0.9358 - val_loss: 0.3481 - val_accuracy: 0.8896
# Epoch 22/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1676 - accuracy: 0.9373 - val_loss: 0.3642 - val_accuracy: 0.8881
# Epoch 23/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1632 - accuracy: 0.9390 - val_loss: 0.3801 - val_accuracy: 0.8867
# Epoch 24/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1607 - accuracy: 0.9399 - val_loss: 0.3818 - val_accuracy: 0.8823
# Epoch 25/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1568 - accuracy: 0.9414 - val_loss: 0.3923 - val_accuracy: 0.8865

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evaluate accuracy

# %%
train_loss, train_acc = cnn.evaluate(train_images,  train_labels, verbose=2)
print('\nTrain accuracy:', train_acc)
# Out:
# 1875/1875 - 2s - loss: 0.1637 - accuracy: 0.9404
#
# Train accuracy: 0.9404000043869019

# %%
test_loss, test_acc = cnn.evaluate(test_images,  test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 0s - loss: 0.3923 - accuracy: 0.8865
#
# Test accuracy: 0.8865000009536743

# %% [markdown]
# ## Make Prediction On Validation Set

# %%
probability_model = tf.keras.Sequential([cnn, tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)

# %% [raw]
# Here, the model has predicted the label for each image in the testing set.

# %%
predictions[0]
#A prediction is an array of 10 numbers. They represent the model's "confidence" that the image corresponds to 
#each of the 10 different articles of clothing.
# Out:
# array([7.2259246e-15, 2.8694305e-16, 1.7897677e-14, 2.2737097e-17,
#        5.7904365e-14, 1.4342150e-05, 2.2062553e-15, 3.4540743e-04,
#        8.8895981e-15, 9.9964023e-01], dtype=float32)

# %% [raw]
#  we can see which label has the highest confidence value:

# %%
np.argmax(predictions[0])
# Out:
# 9

# %% [raw]
# So, the model is most confident that this image is an ankle boot,Examining the test label shows that this classification is correct:

# %%
test_labels[0]
# Out:
# 9

# %% [markdown]
# # Visualization

# %%
def plot_image(i, predictions_array, true_label, img):
      predictions_array, true_label, img = predictions_array, true_label[i], img[i]
      plt.grid(False)
      plt.xticks([])
      plt.yticks([])

      plt.imshow(img, cmap=plt.cm.binary)

      predicted_label = np.argmax(predictions_array)
      if predicted_label == true_label:
        color = 'blue'
      else:
        color = 'red'

      plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                    100*np.max(predictions_array),
                                    class_names[true_label]),
                                    color=color)

def plot_value_array(i, predictions_array, true_label):
      predictions_array, true_label = predictions_array, true_label[i]
      plt.grid(False)
      plt.xticks(range(10))
      plt.yticks([])
      thisplot = plt.bar(range(10), predictions_array, color="#777777")
      plt.ylim([0, 1])
      predicted_label = np.argmax(predictions_array)

      thisplot[predicted_label].set_color('red')
      thisplot[true_label].set_color('blue')

# %% [markdown]
# ## Verify predictions

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
i = 23
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
i = 17
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %% [raw]
# Let's plot several images with their predictions. Note that the model can be wrong even when very confident.

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 6
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### use of trained model to make a prediction about a single image.

# %%
# Grab an image from the test dataset.
img = test_images[2]
print(img.shape)
# Out:
# (28, 28)

# %%
# Add the image to a batch where it's the only member.
img = (np.expand_dims(img,0))
print(img.shape)
# Out:
# (1, 28, 28)

# %% [raw]
# Now predict the correct label for this image:

# %%
predictions_single = probability_model.predict(img)
print(predictions_single)
# Out:
# [[1.0273477e-13 1.0000000e+00 4.2553329e-16 2.7399440e-13 4.1387840e-16
#   6.8488804e-27 2.1962644e-16 0.0000000e+00 6.8259485e-21 5.9373758e-26]]

# %%
plot_value_array(1, predictions_single[0], test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

# %%
np.argmax(predictions_single[0])
# Out:
# 1

# %% [raw]
# And the model predicts a label as expected.

# %% [markdown]
# ## Evaluate the model

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = cnn.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 0s - loss: 0.3923 - accuracy: 0.8865
